# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movie_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
df["ratio_bp"] = df["budget"] / df["popularity"]

# %%
sns.histplot(data=df, x="budget")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='Count'>

# %%
sns.scatterplot(data=df, x="budget", y="popularity")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='popularity'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
sns.countplot(data=df, x="ratio_pb")
# Out:
# <AxesSubplot:xlabel='ratio_pb', ylabel='count'>

# %%
df["ratio_bp"]
# Out:
# 0       1.575404e+06
# 1       2.156991e+06
# 2       2.281685e+06
# 3       2.225923e+06
# 4       5.918912e+06
#             ...
# 4798    1.541718e+04
# 4799    1.400665e+04
# 4800    0.000000e+00
# 4801    0.000000e+00
# 4802    0.000000e+00
# Name: ratio_bp, Length: 4803, dtype: float64

# %%
df["ratio_pb"] = df["popularity"] / df["budget"]

# %%
df["ratio_pb"]
# Out:
# 0       6.347577e-07
# 1       4.636087e-07
# 2       4.382726e-07
# 3       4.492518e-07
# 4       1.689500e-07
#             ...
# 4798    6.486269e-05
# 4799    7.139467e-05
# 4800             inf
# 4801             inf
# 4802             inf
# Name: ratio_pb, Length: 4803, dtype: float64
