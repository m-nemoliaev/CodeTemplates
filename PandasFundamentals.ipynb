# %%
import pandas as pd

# %%
data = pd.read_csv("pirates.csv") #main data
dataNew = pd.read_csv("PirateNewRow.csv") #new row
dataColumn = pd.read_csv("PirateNewCOlumn.csv") #new column

# %%
data.info() 
pd.set_option('display.max_rows', None) #no limits while using print(data["column"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   int64
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
#  16  grogg            1000 non-null   int64
# ...

# %%
#Made by AI

# Define the criterion for a missing object (e.g., missing 'ID' value)
#missing_criterion = data['age'].isnull()

# Use the criterion to filter the rows
#missing_rows = data[missing_criterion]["id"]

# Print the missing rows
#print(missing_rows)

#missing_criterion = data['headband'].isnull()

#missing_rows = data[missing_criterion]["id"]

#print(missing_rows)

#missing_criterion = data['sword.time'].isnull()

#missing_rows = data[missing_criterion]["id"]

#print(missing_rows)

#missing_criterion = data['favorite.pirate'].isnull()

#missing_rows = data[missing_criterion]["id"]

#print(missing_rows)



#was solved by dropna()

# %%
#other student answer

#for index, row in data.iterrows():
#    for column in data.columns:
#        if pd.isna(row[column]):
#            print("Missing data")
#            print(index)
#            print(column)

# %%
#teacher answer

#for column in data.columns:
#    for row in range(len(data["id"])):
#        if pd.isna(data.loc[row, column]):
#            print(row+1)
#            print(column)

# %%
data.nunique()
# Out:
# id                 1000
# sex                   3
# age                  35
# height              882
# weight              393
# headband              2
# college               2
# tattoos              20
# tchests             108
# parrots              23
# favorite.pirate       6
# sword.type            4
# eyepatch              2
# sword.time          324
# beard.length         38
# fav.pixar            15
# grogg                21
# dtype: int64

# %%
avgage = data["age"].mean()
print(avgage)
#average age
# Out:
# 27.35735735735736

# %%
countLess = 0
for i in data["weight"]:
    if i < 45.3592:
        countLess += 1
a = countLess/len(data["weight"])
print(a*100, "%")
# pirates who are lighter than 100 lbs
# Out:
# 0.8 %

# %%
#Made by ChatGPT

# Specify the condition for filtering
condition = data['sex'] == 'female'  # You can change this condition as needed

# Calculate the average of 'age' where 'sex' meets the female
average = data.loc[condition, 'age'].mean()

print("Average of 'age' where 'sex' meets the female:", average)
#average of females
# Out:
# Average of 'age' where 'sex' meets the female: 29.922246220302377

# %%
#Made with AI

highWeight = data["weight"].max()
rowHighWeight = data[data["weight"] == highWeight]
indexRowHighWeight = rowHighWeight.index.tolist()
print(highWeight)
print(indexRowHighWeight)
#highest weight
# Out:
# 105.6
# [1]

# %%
#Made with AI

lowHeight = data["height"].min()
rowLowHeight = data[data["height"] == lowHeight]
indexRowLowHeight = rowLowHeight.index.tolist()
print(lowHeight)
print(indexRowLowHeight)
#lowest height
# Out:
# 129.83
# [38]

# %%
popularMovie = data["fav.pixar"].mode()
print(popularMovie)
#mode of the movies
# Out:
# 0    Inside Out
# Name: fav.pixar, dtype: object

# %%
medEyePatch = data["eyepatch"].median()
avgEyePatch = data["eyepatch"].mean()
print(medEyePatch)
print(avgEyePatch)
#data about eyepatches
# Out:
# 1.0
# 0.658

# %%
data.loc[35, "parrots"] = 1

# %%
#idx = 0
#for i in data["parrots"]:
#    data.loc[idx, "parrots"] = int(1)
#    idx = idx + 1
#doesn't work as intended

# %%
data["parrots"].median()
data["parrots"].mean()
data["parrots"].mode()
#data on parrots
# Out:
# 0    1
# Name: parrots, dtype: int64

# %%
# Use pd.concat() to combine the DataFrames along rows (axis=0)
dataCombine = pd.concat([data, dataNew], axis = 0, ignore_index=True)
#data.info()
#dataCombine.info()

# %%
#sort columns by ["id"] from lowest to highest
dataColumnSorted = dataColumn.sort_values(by="id", ascending=True)
print(dataColumnSorted)
# Out:
#       id         favorite.sea
# 144    0       Gulf of Mexico
# 645    1          Caspian Sea
# 742    2              Red Sea
# 288    3          Chilean Sea
# 837    4           Bering Sea
# 664    5         Labrador Sea
# 983    6            Black Sea
# 858    7           Baltic Sea
# 654    8        Norwegian Sea
# 579    9         Labrador Sea
# 762   10           Ryukyu Sea
# 913   11           Ryukyu Sea
# 451   12        Caribbean Sea
# 351   13       Southern Ocean
# 829   14         Labrador Sea
# 81    15           Aegean Sea
# 4     16        Norwegian Sea
# 49    17          Arabian Sea
# 912   18       Tyrrhenian Sea
# 458   19             Java Sea
# 269   20          Andaman Sea
# 35    21        Greenland Sea
# 819   22       Southern Ocean
# 716   23           Baltic Sea
# 415   24             Sulu Sea
# 2     25         Ligurian Sea
# 581   26        Norwegian Sea
# 309   27           Tasman Sea
# 977   28          Celebes Sea
# 64    29    Mediterranean Sea
# ...

# %%
#merge dataset with new row and with column, adding by id
dataMerge = pd.merge(dataCombine, dataColumnSorted, on="id")
dataMerge = dataMerge.dropna()
#drop all NaN objects (I removed this function from old notebook 7, because it would conflict)
#by the way IDs 1000 and 1001 are deleted by dropna because there is no values in them in column with seas
dataMerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 996 entries, 0 to 998
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               996 non-null    int64
#  1   sex              996 non-null    object
#  2   age              996 non-null    float64
#  3   height           996 non-null    float64
#  4   weight           996 non-null    float64
#  5   headband         996 non-null    object
#  6   college          996 non-null    object
#  7   tattoos          996 non-null    int64
#  8   tchests          996 non-null    int64
#  9   parrots          996 non-null    int64
#  10  favorite.pirate  996 non-null    object
#  11  sword.type       996 non-null    object
#  12  eyepatch         996 non-null    int64
#  13  sword.time       996 non-null    float64
#  14  beard.length     996 non-null    int64
#  15  fav.pixar        996 non-null    object
#  16  grogg            996 non-null    int64
# ...
