# %%
print("Hello World!")
import pandas as pd
import seaborn as sns
# Out:
# Hello World!

# %%
import requests
"""
for i in range(5):
    str = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"
    str[::] = i slice 1 symbol and replace for i
    url = str
    response = requests.get(url, headers=headers)
    response = response.json()
    df = pd.DataFrame(response["results"])
    sns.countplot(data=df, x="original_language")
"""


url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc" #changeable to page={1-40000}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5OTYwM2ZiNzU5YWJiZmUyNjUxZDAwYzdjMzVkNTczZSIsInN1YiI6IjY1MWQ4OWY2OGMyMmMwMDBlNjAzMTlhNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZXdbI3RagRz015k7Np3Z2_hC4kCQNYrUx9PRHlHOk5s"
}


response = requests.get(url, headers=headers)
response = response.json()
mov = response["results"]
df = pd.DataFrame(mov)

# %%
#ch 5
for i in range(20):
    movie = response["results"][i]
    print(movie["popularity"])
    print(movie["genre_ids"])
# Out:
# 69.68
# [28, 878, 12]
# 106.427
# [12, 18, 878]
# 101.113
# [18, 28, 80, 53]
# 89.459
# [28, 12, 14, 878]
# 85.882
# [878, 28, 12]
# 76.651
# [28, 12, 35]
# 166.391
# [12, 28, 878]
# 102.72
# [18]
# 37.398
# [28, 878, 12]
# 78.596
# [53, 80]
# 69.696
# [35, 18, 10749]
# 147.91
# [12, 14]
# 68.944
# [28, 878, 12]
# 57.761
# [18, 37]
# 111.444
# [18, 80]
# 89.193
# [12, 878, 28]
# 69.459
# [28, 878]
# 102.633
# [18, 10749]
# 65.234
# [80, 53, 18]
# 97.202
# [12, 14, 28]

# %%
sns.countplot(data=df, x="original_language")
# Out:
# <AxesSubplot:xlabel='original_language', ylabel='count'>

# %%
df
# Out:
#     adult                     backdrop_path          genre_ids      id  \
# 0   False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg      [28, 878, 12]   27205
# 1   False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg      [12, 18, 878]  157336
# 2   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg   [18, 28, 80, 53]     155
# 3   False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  [28, 12, 14, 878]   19995
# 4   False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg      [878, 28, 12]   24428
# 5   False  /en971MEXui9diirXlogOrPKmsEn.jpg       [28, 12, 35]  293660
# 6   False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg      [12, 28, 878]  299536
# 7   False  /hZkgoQYus5vegHoetLkCJzb17zJ.jpg               [18]     550
# 8   False  /uLtVbjvS1O7gXL8lUOwsFOH4man.jpg      [28, 878, 12]  118340
# 9   False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg           [53, 80]     680
# 10  False  /qdIMHd4sEfJSckfVJfKQvisL02a.jpg    [35, 18, 10749]      13
# 11  False  /hziiv14OpD73u9gAak4XDDfBKa2.jpg           [12, 14]     671
# ...
