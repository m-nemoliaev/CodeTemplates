# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movie_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
df["budget_mil"] = df["budget"] / 1000000
df["ratio_bp"] = df["budget_mil"] / df["popularity"]
df["ratio_pb"] = df["popularity"] / df["budget_mil"]

# %%
sns.scatterplot(data=df, x="budget_mil", y="ratio_bp")
# Out:
# <AxesSubplot:xlabel='budget_mil', ylabel='ratio_bp'>

# %%
sns.residplot(data=df, x="budget_mil", y="popularity")
# Out:
# <AxesSubplot:xlabel='budget_mil', ylabel='popularity'>

# %%
count = 0
for i in range(len(df["budget_mil"])):
    if df["budget_mil"][i] >= 150:
        count += 1
print(count/len(df["budget_mil"])*100 )
# Out:
# 2.998126171143036

# %%
count = 0
for i in range(len(df["popularity"])):
    if df["popularity"][i] <= 12.9216:
        count += 1
print(count/len(df["popularity"])*100)
# Out:
# 50.01041016031647
